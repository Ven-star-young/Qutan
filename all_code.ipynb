# %%
from clickhouse_connect import get_client
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates

client = get_client(
    host="chdb.tradegdb.com",
    port=8123,
    username="wanghao",
    password="T8yK1pR4bM9cH2Va"
)

# %%
def get_all_cancel_orders(date: str = '2025-03-03'):
    """
    获取指定日期所有撤单的编号
    """
    sql = f"""
    SELECT 
        code,
        date_time,
        trade_flag,
        exg,
        bidno,  -- 撤买单的原始编号
        askno   -- 撤卖单的原始编号
    FROM stock_base.zb 
    WHERE date = '{date}'
        AND date_time >= '{date} 09:15:00'
        AND date_time <= '{date} 09:20:00'  -- 撤单只在09:20前
        AND trade_flag = '4'  -- 撤单标识
        AND (bidno IS NOT NULL OR askno IS NOT NULL)
        AND exg = '1'
    """
    
    df = client.query_df(sql)
    cancel_ids = []
    for _, row in df.iterrows():
        if pd.notna(row['bidno']) and int(row['bidno']) > 0:
            cancel_ids.append(int(row['bidno']))  # 撤买单编号
        elif pd.notna(row['askno']) and int(row['askno']) > 0:
            cancel_ids.append(int(row['askno']))  # 撤卖单编号

    return df, cancel_ids

# 使用
cancel_df, cancel_ids = get_all_cancel_orders('2025-03-03')
print(f"\n撤单编号示例: {cancel_ids[:10]}")  # 前10个
# Out:
# 撤单编号示例: [155038, 159265, 224459, 228895, 183042, 175299, 232111, 232117, 224294, 91016]

# %%
def get_all_data(code: str, date: str = '2025-03-03', cancel_ids: list = []):
    """
    获取股票数据，并排除被撤掉的订单
    cancel_ids: 从撤单表获取的所有撤单编号列表
    """
    # 基础查询
    sql = f"""
    SELECT 
        time_int,
        price,
        volume,
        side,
        ordno,
        type,
        trade_flag
    FROM stock_base.zb 
    WHERE code = '{code}'
        AND date = '{date}'
        AND date_time >= '{date} 09:15:00'
        AND date_time <= '{date} 09:25:00'
        AND type IS NOT NULL  -- 挂单数据
        AND price IS NOT NULL
        AND volume IS NOT NULL
    ORDER BY time_int
    """
    
    df = client.query_df(sql)
    
    if df.empty:
        return df
    
    # 在Python中过滤：排除被撤掉的订单
    if cancel_ids:
        # 过滤掉ordno在cancel_ids中的订单
        # 注意：ordno可能是空值，先处理
        mask = ~df['ordno'].isin(cancel_ids)
        df = df[mask].copy()
        
        print(f"  过滤撤单: 原始{len(df)+len(cancel_ids)}条 → 剩余{len(df)}条")
    
    return df

# %%
def get_all_codes(date: str = '2025-03-03'):
    sql = f"""
    SELECT DISTINCT code
    FROM stock_base.zb 
    WHERE date = '{date}'
        AND date_time >= '{date} 09:15:00'
        AND date_time <= '{date} 09:25:00'
        AND type IS NOT NULL
        AND price IS NOT NULL
    LIMIT 200 --限制股票数
    """
    
    try:
        df = client.query_df(sql)
        return df['code'].tolist() if not df.empty else []
    except Exception as e:
        print(f"查询失败: {e}")
        return []

# %%
def calculate_opening_price(buy_orders, sell_orders, prev_close):
    """
    完整的开盘价计算，包含规则三
    """
    if prev_close is None:
        prev_close = 0
    
    # 1. 获取所有价格
    all_prices = sorted(set(
        list(buy_orders['price'].unique()) + 
        list(sell_orders['price'].unique())
    ))
    
    max_volume = 0
    candidate_prices = []
    
    # 2. 找出所有可能价格中满足条件三的最大成交量
    for price in all_prices:
        # 买方累计：价格>=当前价
        buy_total = buy_orders[buy_orders['price'] >= price]['volume'].sum()
        # 卖方累计：价格<=当前价
        sell_total = sell_orders[sell_orders['price'] <= price]['volume'].sum()
        volume = min(buy_total, sell_total)
        
        if volume == 0:
            continue
        
        # 检查规则三：该价格相同的买方或卖方至少有一方全部成交
        buy_at_price = buy_orders[buy_orders['price'] == price]['volume'].sum()
        sell_at_price = sell_orders[sell_orders['price'] == price]['volume'].sum()
        
        # 条件三检查
        condition_three = False
        if buy_at_price > 0 and sell_at_price > 0:
            # 双方都有挂单，必须至少一方全部成交
            # 买单能成交多少（在总成交量内）
            buy_can_trade = min(buy_at_price, volume)
            # 卖单能成交多少
            sell_can_trade = min(sell_at_price, volume)
            
            condition_three = (buy_can_trade == buy_at_price) or (sell_can_trade == sell_at_price)
        else:
            # 只有一方有挂单，自动满足
            condition_three = True
        
        if not condition_three:
            continue  # 不满足规则三，跳过
        
        # 更新最大成交量
        if volume > max_volume:
            max_volume = volume
            candidate_prices = [price]
        elif volume == max_volume:
            candidate_prices.append(price)
    
    if not candidate_prices:
        return prev_close if prev_close > 0 else 0, 0
    
    # 3. 只有一个价格
    if len(candidate_prices) == 1:
        return candidate_prices[0], max_volume
    
    # 4. 多个价格：买卖量差最小
    min_diff = float('inf')
    second_candidates = []
    
    for price in candidate_prices:
        buy_above = buy_orders[buy_orders['price'] >= price]['volume'].sum()
        sell_below = sell_orders[sell_orders['price'] <= price]['volume'].sum()
        diff = abs(buy_above - sell_below)
        
        if diff < min_diff:
            min_diff = diff
            second_candidates = [price]
        elif diff == min_diff:
            second_candidates.append(price)
    
    if len(second_candidates) == 1:
        return second_candidates[0], max_volume
    
    # 5. 取最接近前收盘价
    if prev_close == 0:
        return second_candidates[len(second_candidates)//2], max_volume
    
    closest_price = min(second_candidates, key=lambda p: abs(p - prev_close))
    return closest_price, max_volume

# %%
# 从日线表获取真实开盘价
def get_real_opening_price(code, date:str = '2025-03-03'):
    sql = f"""
    SELECT 
        open,
        pclose 
    FROM stock_base.daily 
    WHERE code = '{code}' AND date = '{date}'
    LIMIT 1
    """
    
    try:
        df = client.query_df(sql)
        if not df.empty:
            return float(df.iloc[0]['open']),float(df.iloc[0]['pclose'])
    except Exception as e:
        print(f"查询失败: {e}")
    
    return None

# %%
cancel_df, cancel_ids = get_all_cancel_orders('2025-03-03')
codes = np.unique(get_all_codes(date='2025-03-03'))
all_codes = len(codes)
print(f"共有{all_codes}支股票")
count = 0
wrong_code = {}

for code in codes:
    df = get_all_data(code,cancel_ids=cancel_ids)
    buy_orders = df[df['side'] == b'B'].copy()
    sell_orders = df[df['side'] == b'S'].copy()
    real_price, prev_close = get_real_opening_price(code)

    best_price, max_volume = calculate_opening_price(buy_orders,sell_orders,prev_close)
    
    
    print(f"计算:{best_price}     实际:{real_price}")
    if(real_price == best_price):
        count+=1
    else:
        wrong_code[code] = (best_price, real_price)

print(f"计算正确{count}支股票")
print(wrong_code)
# Out:
# 共有200支股票
#   过滤撤单: 原始73260条 → 剩余167条
# 计算:6.27     实际:6.28
#   过滤撤单: 原始73449条 → 剩余356条
# 计算:2.85     实际:2.87
#   过滤撤单: 原始73372条 → 剩余279条
# 计算:9.93     实际:9.93
#   过滤撤单: 原始75430条 → 剩余2337条
# 计算:20.32     实际:20.31
#   过滤撤单: 原始73410条 → 剩余317条
# 计算:16.18     实际:16.18
#   过滤撤单: 原始73200条 → 剩余107条
# 计算:15.07     实际:15.07
#   过滤撤单: 原始76249条 → 剩余3156条
# 计算:26.5     实际:26.5
#   过滤撤单: 原始75726条 → 剩余2633条
# 计算:4.29     实际:4.29
#   过滤撤单: 原始73685条 → 剩余592条
# 计算:8.8     实际:8.8
#   过滤撤单: 原始74764条 → 剩余1671条
# 计算:22.0     实际:22.0
#   过滤撤单: 原始73420条 → 剩余327条
# 计算:15.8     实际:15.8
#   过滤撤单: 原始73795条 → 剩余702条
# 计算:18.3     实际:18.29
#   过滤撤单: 原始73461条 → 剩余368条
# 计算:5.77     实际:5.78
#   过滤撤单: 原始73484条 → 剩余391条
# 计算:5.87     实际:5.87
#   过滤撤单: 原始73211条 → 剩余118条
# 计算:1.86     实际:1.86
#   过滤撤单: 原始75176条 → 剩余2083条
# 计算:16.44     实际:16.44
#   过滤撤单: 原始73360条 → 剩余267条
# 计算:4.64     实际:4.64
#   过滤撤单: 原始73566条 → 剩余473条
# 计算:5.89     实际:5.89
#   过滤撤单: 原始73561条 → 剩余468条
# 计算:10.35     实际:10.35
#   过滤撤单: 原始76051条 → 剩余2958条
# 计算:6.37     实际:6.36
#   过滤撤单: 原始74096条 → 剩余1003条
# 计算:6.23     实际:6.22
#   过滤撤单: 原始73535条 → 剩余442条
# 计算:16.5     实际:16.42
#   过滤撤单: 原始73616条 → 剩余523条
# 计算:6.91     实际:6.91
#   过滤撤单: 原始74040条 → 剩余947条
# 计算:10.83     实际:10.83
#   过滤撤单: 原始74403条 → 剩余1310条
# 计算:17.13     实际:17.16
#   过滤撤单: 原始73463条 → 剩余370条
# 计算:6.66     实际:6.65
#   过滤撤单: 原始73255条 → 剩余162条
# 计算:9.43     实际:9.43
#   过滤撤单: 原始75520条 → 剩余2427条
# 计算:5.75     实际:5.77
#   过滤撤单: 原始74047条 → 剩余954条
# 计算:2.22     实际:2.22
#   过滤撤单: 原始73263条 → 剩余170条
# 计算:10.59     实际:10.59
#   过滤撤单: 原始73833条 → 剩余740条
# 计算:3.47     实际:3.47
#   过滤撤单: 原始73475条 → 剩余382条
# 计算:10.53     实际:10.53
#   过滤撤单: 原始74816条 → 剩余1723条
# 计算:5.55     实际:5.55
#   过滤撤单: 原始74046条 → 剩余953条
# 计算:12.68     实际:12.6
#   过滤撤单: 原始73609条 → 剩余516条
# 计算:5.15     实际:5.15
#   过滤撤单: 原始75958条 → 剩余2865条
# 计算:16.29     实际:16.29
#   过滤撤单: 原始73985条 → 剩余892条
# 计算:27.51     实际:27.51
#   过滤撤单: 原始74092条 → 剩余999条
# 计算:446.33     实际:446.33
#   过滤撤单: 原始73442条 → 剩余349条
# 计算:3.9     实际:3.89
#   过滤撤单: 原始73401条 → 剩余308条
# 计算:10.22     实际:10.22
#   过滤撤单: 原始76801条 → 剩余3708条
# 计算:5.49     实际:5.49
#   过滤撤单: 原始73484条 → 剩余391条
# 计算:4.34     实际:4.34
#   过滤撤单: 原始73287条 → 剩余194条
# 计算:16.83     实际:16.83
#   过滤撤单: 原始73539条 → 剩余446条
# 计算:3.77     实际:3.77
#   过滤撤单: 原始73882条 → 剩余789条
# 计算:7.55     实际:7.55
#   过滤撤单: 原始73699条 → 剩余606条
# 计算:7.01     实际:7.0
#   过滤撤单: 原始73513条 → 剩余420条
# 计算:5.25     实际:5.25
#   过滤撤单: 原始73378条 → 剩余285条
# 计算:50.99     实际:50.99
#   过滤撤单: 原始76423条 → 剩余3330条
# 计算:11.36     实际:11.36
#   过滤撤单: 原始74159条 → 剩余1066条
# 计算:13.96     实际:13.96
#   过滤撤单: 原始76837条 → 剩余3744条
# 计算:3.41     实际:3.41
#   过滤撤单: 原始73501条 → 剩余408条
# 计算:6.85     实际:6.87
#   过滤撤单: 原始73795条 → 剩余702条
# 计算:8.12     实际:8.13
#   过滤撤单: 原始73436条 → 剩余343条
# 计算:34.5     实际:34.41
#   过滤撤单: 原始73330条 → 剩余237条
# 计算:20.22     实际:20.11
#   过滤撤单: 原始73218条 → 剩余125条
# 计算:13.16     实际:13.16
#   过滤撤单: 原始73768条 → 剩余675条
# 计算:4.09     实际:4.09
#   过滤撤单: 原始73120条 → 剩余27条
# 计算:6.01     实际:6.01
#   过滤撤单: 原始73310条 → 剩余217条
# 计算:24.63     实际:24.63
#   过滤撤单: 原始73372条 → 剩余279条
# 计算:42.25     实际:42.13
#   过滤撤单: 原始73560条 → 剩余467条
# 计算:16.1     实际:16.1
#   过滤撤单: 原始74654条 → 剩余1561条
# 计算:7.48     实际:7.48
#   过滤撤单: 原始73262条 → 剩余169条
# 计算:12.87     实际:12.87
#   过滤撤单: 原始73213条 → 剩余120条
# 计算:26.32     实际:26.32
#   过滤撤单: 原始73246条 → 剩余153条
# 计算:24.67     实际:24.66
#   过滤撤单: 原始73924条 → 剩余831条
# 计算:24.35     实际:24.35
#   过滤撤单: 原始73225条 → 剩余132条
# 计算:21.82     实际:21.82
#   过滤撤单: 原始73176条 → 剩余83条
# 计算:77.88     实际:77.88
#   过滤撤单: 原始73491条 → 剩余398条
# 计算:20.32     实际:20.32
#   过滤撤单: 原始73307条 → 剩余214条
# 计算:6.27     实际:6.27
#   过滤撤单: 原始73553条 → 剩余460条
# 计算:16.82     实际:16.82
#   过滤撤单: 原始73620条 → 剩余527条
# 计算:15.15     实际:15.15
#   过滤撤单: 原始74207条 → 剩余1114条
# 计算:2.44     实际:2.44
#   过滤撤单: 原始74576条 → 剩余1483条
# 计算:3.89     实际:3.9
#   过滤撤单: 原始73937条 → 剩余844条
# 计算:18.1     实际:18.1
#   过滤撤单: 原始73759条 → 剩余666条
# 计算:17.59     实际:17.59
#   过滤撤单: 原始73267条 → 剩余174条
# 计算:7.48     实际:7.48
#   过滤撤单: 原始73799条 → 剩余706条
# 计算:20.96     实际:20.96
#   过滤撤单: 原始73510条 → 剩余417条
# 计算:12.61     实际:12.61
#   过滤撤单: 原始73377条 → 剩余284条
# 计算:5.02     实际:5.02
#   过滤撤单: 原始74104条 → 剩余1011条
# 计算:17.65     实际:17.66
#   过滤撤单: 原始73325条 → 剩余232条
# 计算:8.99     实际:8.99
#   过滤撤单: 原始75491条 → 剩余2398条
# 计算:38.68     实际:38.54
#   过滤撤单: 原始73608条 → 剩余515条
# 计算:12.91     实际:12.91
#   过滤撤单: 原始73587条 → 剩余494条
# 计算:17.94     实际:17.94
#   过滤撤单: 原始73374条 → 剩余281条
# 计算:34.8     实际:34.8
#   过滤撤单: 原始73909条 → 剩余816条
# 计算:37.99     实际:37.99
#   过滤撤单: 原始73474条 → 剩余381条
# 计算:12.54     实际:12.54
#   过滤撤单: 原始73574条 → 剩余481条
# 计算:63.58     实际:63.58
#   过滤撤单: 原始73888条 → 剩余795条
# 计算:29.5     实际:29.52
#   过滤撤单: 原始73263条 → 剩余170条
# 计算:13.1     实际:13.1
#   过滤撤单: 原始74273条 → 剩余1180条
# 计算:25.9     实际:25.84
#   过滤撤单: 原始73344条 → 剩余251条
# 计算:6.6     实际:6.61
#   过滤撤单: 原始73268条 → 剩余175条
# 计算:18.53     实际:18.53
#   过滤撤单: 原始73343条 → 剩余250条
# 计算:19.8     实际:19.8
#   过滤撤单: 原始73326条 → 剩余233条
# 计算:17.58     实际:17.58
#   过滤撤单: 原始73774条 → 剩余681条
# 计算:23.59     实际:23.54
#   过滤撤单: 原始73373条 → 剩余280条
# 计算:48.3     实际:48.3
#   过滤撤单: 原始73266条 → 剩余173条
# 计算:9.2     实际:9.2
#   过滤撤单: 原始74722条 → 剩余1629条
# 计算:21.87     实际:21.87
#   过滤撤单: 原始73409条 → 剩余316条
# 计算:39.51     实际:39.51
#   过滤撤单: 原始73367条 → 剩余274条
# 计算:8.36     实际:8.36
#   过滤撤单: 原始73252条 → 剩余159条
# 计算:18.43     实际:18.43
#   过滤撤单: 原始73467条 → 剩余374条
# 计算:19.3     实际:19.3
#   过滤撤单: 原始73398条 → 剩余305条
# 计算:37.75     实际:37.75
#   过滤撤单: 原始73255条 → 剩余162条
# 计算:34.5     实际:34.5
#   过滤撤单: 原始73442条 → 剩余349条
# 计算:32.72     实际:32.71
#   过滤撤单: 原始73234条 → 剩余141条
# 计算:32.03     实际:32.09
#   过滤撤单: 原始73391条 → 剩余298条
# 计算:51.33     实际:51.33
#   过滤撤单: 原始73295条 → 剩余202条
# 计算:14.83     实际:14.83
#   过滤撤单: 原始73332条 → 剩余239条
# 计算:9.81     实际:9.81
#   过滤撤单: 原始73387条 → 剩余294条
# 计算:29.62     实际:29.6
#   过滤撤单: 原始74172条 → 剩余1079条
# 计算:103.62     实际:103.34
#   过滤撤单: 原始73610条 → 剩余517条
# 计算:18.25     实际:18.16
#   过滤撤单: 原始73639条 → 剩余546条
# 计算:60.01     实际:60.01
#   过滤撤单: 原始73495条 → 剩余402条
# 计算:6.2     实际:6.25
#   过滤撤单: 原始73794条 → 剩余701条
# 计算:11.8     实际:11.8
#   过滤撤单: 原始75527条 → 剩余2434条
# 计算:11.39     实际:11.39
#   过滤撤单: 原始73373条 → 剩余280条
# 计算:4.46     实际:4.41
#   过滤撤单: 原始76106条 → 剩余3013条
# 计算:7.32     实际:7.3
#   过滤撤单: 原始73422条 → 剩余329条
# 计算:8.7     实际:8.7
#   过滤撤单: 原始78278条 → 剩余5185条
# 计算:1.55     实际:1.55
#   过滤撤单: 原始73332条 → 剩余239条
# 计算:7.18     实际:7.05
#   过滤撤单: 原始73218条 → 剩余125条
# 计算:5.56     实际:5.6
#   过滤撤单: 原始73551条 → 剩余458条
# 计算:6.18     实际:6.19
#   过滤撤单: 原始73397条 → 剩余304条
# 计算:7.76     实际:7.74
#   过滤撤单: 原始73403条 → 剩余310条
# 计算:4.83     实际:4.83
#   过滤撤单: 原始73592条 → 剩余499条
# 计算:13.7     实际:14.67
#   过滤撤单: 原始74123条 → 剩余1030条
# 计算:3.58     实际:3.48
#   过滤撤单: 原始73360条 → 剩余267条
# 计算:4.33     实际:4.41
#   过滤撤单: 原始73462条 → 剩余369条
# 计算:10.84     实际:10.84
#   过滤撤单: 原始75047条 → 剩余1954条
# 计算:3.26     实际:3.22
#   过滤撤单: 原始73308条 → 剩余215条
# 计算:4.36     实际:4.36
#   过滤撤单: 原始73314条 → 剩余221条
# 计算:3.89     实际:3.89
#   过滤撤单: 原始75443条 → 剩余2350条
# 计算:26.46     实际:26.32
#   过滤撤单: 原始73321条 → 剩余228条
# 计算:24.0     实际:24.0
#   过滤撤单: 原始74009条 → 剩余916条
# 计算:5.94     实际:5.94
#   过滤撤单: 原始73936条 → 剩余843条
# 计算:56.35     实际:56.34
#   过滤撤单: 原始73454条 → 剩余361条
# 计算:10.05     实际:10.13
#   过滤撤单: 原始73508条 → 剩余415条
# 计算:4.86     实际:4.86
#   过滤撤单: 原始73638条 → 剩余545条
# 计算:4.58     实际:4.58
#   过滤撤单: 原始73771条 → 剩余678条
# 计算:12.75     实际:12.75
#   过滤撤单: 原始80912条 → 剩余7819条
# 计算:5.14     实际:5.14
#   过滤撤单: 原始78506条 → 剩余5413条
# 计算:50.5     实际:50.55
#   过滤撤单: 原始74177条 → 剩余1084条
# 计算:48.21     实际:48.21
#   过滤撤单: 原始73425条 → 剩余332条
# 计算:7.94     实际:8.01
#   过滤撤单: 原始75441条 → 剩余2348条
# 计算:5.9     实际:5.9
#   过滤撤单: 原始73422条 → 剩余329条
# 计算:17.12     实际:17.15
#   过滤撤单: 原始73233条 → 剩余140条
# 计算:9.27     实际:9.17
#   过滤撤单: 原始73185条 → 剩余92条
# 计算:17.08     实际:17.08
#   过滤撤单: 原始74437条 → 剩余1344条
# 计算:26.48     实际:26.0
#   过滤撤单: 原始73560条 → 剩余467条
# 计算:33.54     实际:33.54
#   过滤撤单: 原始73250条 → 剩余157条
# 计算:15.57     实际:15.55
#   过滤撤单: 原始73243条 → 剩余150条
# 计算:25.82     实际:26.01
#   过滤撤单: 原始73348条 → 剩余255条
# 计算:14.38     实际:14.32
#   过滤撤单: 原始73312条 → 剩余219条
# 计算:54.16     实际:54.24
#   过滤撤单: 原始73153条 → 剩余60条
# 计算:37.5     实际:37.5
#   过滤撤单: 原始73282条 → 剩余189条
# 计算:41.8     实际:41.75
#   过滤撤单: 原始73336条 → 剩余243条
# 计算:16.76     实际:16.68
#   过滤撤单: 原始73209条 → 剩余116条
# 计算:14.91     实际:14.91
#   过滤撤单: 原始73338条 → 剩余245条
# 计算:28.49     实际:28.7
#   过滤撤单: 原始73553条 → 剩余460条
# 计算:97.0     实际:96.5
#   过滤撤单: 原始73308条 → 剩余215条
# 计算:21.2     实际:20.98
#   过滤撤单: 原始73730条 → 剩余637条
# 计算:15.9     实际:15.9
#   过滤撤单: 原始73299条 → 剩余206条
# 计算:11.34     实际:11.34
#   过滤撤单: 原始73197条 → 剩余104条
# 计算:36.1     实际:36.12
#   过滤撤单: 原始74545条 → 剩余1452条
# 计算:7.07     实际:6.43
#   过滤撤单: 原始73722条 → 剩余629条
# 计算:5.1     实际:5.1
#   过滤撤单: 原始73457条 → 剩余364条
# 计算:13.12     实际:13.06
#   过滤撤单: 原始73241条 → 剩余148条
# 计算:7.92     实际:7.96
#   过滤撤单: 原始73448条 → 剩余355条
# 计算:58.38     实际:58.35
#   过滤撤单: 原始73380条 → 剩余287条
# 计算:48.6     实际:48.6
#   过滤撤单: 原始73578条 → 剩余485条
# 计算:79.81     实际:79.81
#   过滤撤单: 原始73199条 → 剩余106条
# 计算:14.15     实际:14.09
#   过滤撤单: 原始73288条 → 剩余195条
# 计算:3.23     实际:3.22
#   过滤撤单: 原始73361条 → 剩余268条
# 计算:13.07     实际:13.19
#   过滤撤单: 原始73167条 → 剩余74条
# 计算:6.5     实际:6.5
#   过滤撤单: 原始73386条 → 剩余293条
# 计算:23.49     实际:21.31
#   过滤撤单: 原始73209条 → 剩余116条
# 计算:6.44     实际:6.43
#   过滤撤单: 原始73443条 → 剩余350条
# 计算:6.56     实际:6.55
#   过滤撤单: 原始73462条 → 剩余369条
# 计算:66.28     实际:66.43
#   过滤撤单: 原始73276条 → 剩余183条
# 计算:26.8     实际:26.81
#   过滤撤单: 原始73236条 → 剩余143条
# 计算:12.44     实际:12.44
#   过滤撤单: 原始73333条 → 剩余240条
# 计算:215.3     实际:215.3
#   过滤撤单: 原始73464条 → 剩余371条
# 计算:9.18     实际:9.18
#   过滤撤单: 原始73674条 → 剩余581条
# 计算:17.06     实际:17.12
#   过滤撤单: 原始73224条 → 剩余131条
# 计算:7.79     实际:7.79
#   过滤撤单: 原始74048条 → 剩余955条
# 计算:5.8     实际:5.8
#   过滤撤单: 原始73801条 → 剩余708条
# 计算:204.31     实际:204.67
#   过滤撤单: 原始73461条 → 剩余368条
# 计算:92.18     实际:92.18
#   过滤撤单: 原始73366条 → 剩余273条
# 计算:66.23     实际:63.3
#   过滤撤单: 原始73410条 → 剩余317条
# 计算:282.49     实际:280.89
#   过滤撤单: 原始73247条 → 剩余154条
# 计算:19.1     实际:17.65
#   过滤撤单: 原始73233条 → 剩余140条
# 计算:15.56     实际:15.79
#   过滤撤单: 原始74288条 → 剩余1195条
# 计算:160.38     实际:160.05
#   过滤撤单: 原始73145条 → 剩余52条
# 计算:34.45     实际:34.45
#   过滤撤单: 原始73368条 → 剩余275条
# 计算:46.58     实际:46.32
#   过滤撤单: 原始73199条 → 剩余106条
# 计算:163.06     实际:161.0
#   过滤撤单: 原始73145条 → 剩余52条
# 计算:30.98     实际:30.98
#   过滤撤单: 原始73419条 → 剩余326条
# 计算:43.79     实际:43.99
# 计算正确117支股票
# {np.str_('000007'): (np.float64(6.27), 6.28), np.str_('000010'): (np.float64(2.85), 2.87), np.str_('000021'): (np.float64(20.32), 20.31), np.str_('000777'): (np.float64(18.3), 18.29), np.str_('000788'): (np.float64(5.77), 5.78), np.str_('002027'): (np.float64(6.37), 6.36), np.str_('002030'): (np.float64(6.23), 6.22), np.str_('002034'): (np.float64(16.5), 16.42), np.str_('002045'): (np.float64(17.13), 17.16), np.str_('002199'): (np.float64(6.66), 6.65), np.str_('002207'): (np.float64(5.75), 5.77), np.str_('002229'): (np.float64(12.68), 12.6), np.str_('002375'): (np.float64(3.9), 3.89), np.str_('002588'): (np.float64(7.01), 7.0), np.str_('002614'): (np.float64(6.85), 6.87), np.str_('002926'): (np.float64(8.12), 8.13), np.str_('002933'): (np.float64(34.5), 34.41), np.str_('002937'): (np.float64(20.22), 20.11), np.str_('002959'): (np.float64(42.25), 42.13), np.str_('002980'): (np.float64(24.67), 24.66), np.str_('300189'): (np.float64(3.89), 3.9), np.str_('300468'): (np.float64(17.65), 17.66), np.str_('300475'): (np.float64(38.68), 38.54), np.str_('300783'): (np.float64(29.5), 29.52), np.str_('300790'): (np.float64(25.9), 25.84), np.str_('300798'): (np.float64(6.6), 6.61), np.str_('300817'): (np.float64(23.59), 23.54), np.str_('301281'): (np.float64(32.72), 32.71), np.str_('301285'): (np.float64(32.03), 32.09), np.str_('301300'): (np.float64(29.62), 29.6), np.str_('301308'): (np.float64(103.62), 103.34), np.str_('301311'): (np.float64(18.25), 18.16), np.str_('600195'): (np.float64(6.2), 6.25), np.str_('600207'): (np.float64(4.46), 4.41), np.str_('600210'): (np.float64(7.32), 7.3), np.str_('600229'): (np.float64(7.18), 7.05), np.str_('600232'): (np.float64(5.56), 5.6), np.str_('600236'): (np.float64(6.18), 6.19), np.str_('600636'): (np.float64(7.76), 7.74), np.str_('600650'): (np.float64(13.7), 14.67), np.str_('600654'): (np.float64(3.58), 3.48), np.str_('600658'): (np.float64(4.33), 4.41), np.str_('600665'): (np.float64(3.26), 3.22), np.str_('600690'): (np.float64(26.46), 26.32), np.str_('600702'): (np.float64(56.35), 56.34), np.str_('600706'): (np.float64(10.05), 10.13), np.str_('601318'): (np.float64(50.5), 50.55), np.str_('601369'): (np.float64(7.94), 8.01), np.str_('603206'): (np.float64(17.12), 17.15), np.str_('603213'): (np.float64(9.27), 9.17), np.str_('603220'): (np.float64(26.48), 26.0), np.str_('603231'): (np.float64(15.57), 15.55), np.str_('603235'): (np.float64(25.82), 26.01), np.str_('603239'): (np.float64(14.38), 14.32), np.str_('603260'): (np.float64(54.16), 54.24), np.str_('603275'): (np.float64(41.8), 41.75), np.str_('603279'): (np.float64(16.76), 16.68), np.str_('603286'): (np.float64(28.49), 28.7), np.str_('603297'): (np.float64(97.0), 96.5), np.str_('603301'): (np.float64(21.2), 20.98), np.str_('603312'): (np.float64(36.1), 36.12), np.str_('603316'): (np.float64(7.07), 6.43), np.str_('603327'): (np.float64(13.12), 13.06), np.str_('603330'): (np.float64(7.92), 7.96), np.str_('603338'): (np.float64(58.38), 58.35), np.str_('603356'): (np.float64(14.15), 14.09), np.str_('603363'): (np.float64(3.23), 3.22), np.str_('603367'): (np.float64(13.07), 13.19), np.str_('603381'): (np.float64(23.49), 21.31), np.str_('603385'): (np.float64(6.44), 6.43), np.str_('603389'): (np.float64(6.56), 6.55), np.str_('603392'): (np.float64(66.28), 66.43), np.str_('603396'): (np.float64(26.8), 26.81), np.str_('603477'): (np.float64(17.06), 17.12), np.str_('688012'): (np.float64(204.31), 204.67), np.str_('688023'): (np.float64(66.23), 63.3), np.str_('688027'): (np.float64(282.49), 280.89), np.str_('688030'): (np.float64(19.1), 17.65), np.str_('688038'): (np.float64(15.56), 15.79), np.str_('688041'): (np.float64(160.38), 160.05), np.str_('688049'): (np.float64(46.58), 46.32), np.str_('688052'): (np.float64(163.06), 161.0), np.str_('688063'): (np.float64(43.79), 43.99)}
