# %%
from clickhouse_connect import get_client
import pandas as pd

client = get_client(
    host="xx",
    port=xx,
    username="xx",
    password="xx"
)

# %% [markdown]
# ## 基础信息关键字

# %%
sql1 = 'DESCRIBE TABLE stock_base.zb'
df_structure = client.query_df(sql1)
print("表结构：")
display(df_structure)
# Out:
# 表结构：
#           name                            type default_type  \
# 0         code                          String
# 1         date                            Date
# 2    date_time  DateTime64(3, 'Asia/Shanghai')
# 3          exg                           UInt8
# 4     time_int                           Int32
# 5        price               Nullable(Float64)
# 6       volume                 Nullable(Int64)
# 7         side                  FixedString(1)
# 8         type                  FixedString(1)
# 9   trade_flag                  FixedString(1)
# 10        chno                          UInt64
# 11       bidno                 Nullable(Int64)
# 12       askno                 Nullable(Int64)
# 13       ordno                 Nullable(Int64)
# 14       seqno                          UInt64
# 15       ctype                  FixedString(1)
# 16      cbidno                 Nullable(Int64)
# 17      caskno                 Nullable(Int64)
#
# ...

# %% [markdown]
# ## 日线数据关键字

# %%
sql2 = 'DESCRIBE TABLE stock_base.daily'
df_structure = client.query_df(sql2)
print("表结构：")
display(df_structure)
# Out:
# 表结构：
#        name               type default_type default_expression  \
# 0      code             String
# 1      date               Date
# 2       exg              UInt8
# 3      open  Nullable(Float64)
# 4      high  Nullable(Float64)
# 5       low  Nullable(Float64)
# 6     close  Nullable(Float64)
# 7    pclose  Nullable(Float64)
# 8    change  Nullable(Float64)
# 9   pct_chg  Nullable(Float64)
# 10   volume    Nullable(Int64)
# 11   amount  Nullable(Float64)
# 12      hfq  Nullable(Float64)
# 13  ztprice  Nullable(Float64)
# 14  dtprice  Nullable(Float64)
# 15  omax_op  Nullable(Float64)
# 16  omin_op  Nullable(Float64)
#
#                  comment codec_expression ttl_expression
# 0                   证券代码
# 1                     日期
# 2   交易所类型,
#
#
# 1为深市，2为沪市
# 3                    开盘价
# 4                    最高价
# 5                    最低价
# 6                    收盘价
# 7                    昨收价
# 8                    涨跌额
# 9               涨跌幅(未复权)
# 10                成交量(股)
# ...

# %% [markdown]
# ## 分钟线数据

# %%
sql2 = 'DESCRIBE TABLE stock_base.m1'
df_structure = client.query_df(sql2)
print("表结构：")
display(df_structure)
# Out:
# 表结构：
#          name                       type default_type default_expression  \
# 0        code                     String
# 1   date_time  DateTime('Asia/Shanghai')
# 2         exg                      UInt8
# 3    time_int                      Int32
# 4        open          Nullable(Float64)
# 5       close          Nullable(Float64)
# 6        high          Nullable(Float64)
# 7         low          Nullable(Float64)
# 8      volume          Nullable(Float64)
# 9      amount          Nullable(Float64)
# 10       date                       Date
#
#                     comment codec_expression ttl_expression
# 0                      证券代码
# 1                      日期详情
# 2   交易所的标识，深市是1，沪市是2, 北交所是3
# 3                    日期详情整形
# 4
# 5
# 6
# 7
# 8
# 9
# 10                       日期

# %% [markdown]
# ## 全天快照

# %%
sql2 = 'DESCRIBE TABLE stock_base.tk'
df_structure = client.query_df(sql2)
print("表结构：")
display(df_structure)
# Out:
# 表结构：
#                   name                       type default_type  \
# 0                 code                     String
# 1            date_time  DateTime('Asia/Shanghai')
# 2             time_int                      Int32
# 3                  exg                      UInt8
# 4                 date                       Date
# 5               pclose          Nullable(Float64)
# 6                 open          Nullable(Float64)
# 7                 high          Nullable(Float64)
# 8                  low          Nullable(Float64)
# 9                 last          Nullable(Float64)
# 10        total_volume            Nullable(Int64)
# 11         total_value          Nullable(Float64)
# 12                bid1          Nullable(Float64)
# 13                bid2          Nullable(Float64)
# 14                bid3          Nullable(Float64)
# 15                bid4          Nullable(Float64)
# 16                bid5          Nullable(Float64)
# ...

# %% [markdown]
# ## 全天逐笔数据

# %%
sql2 = 'DESCRIBE TABLE stock_base.zb'
df_structure = client.query_df(sql2)
print("表结构：")
display(df_structure)
# Out:
# 表结构：
#           name                            type default_type  \
# 0         code                          String
# 1         date                            Date
# 2    date_time  DateTime64(3, 'Asia/Shanghai')
# 3          exg                           UInt8
# 4     time_int                           Int32
# 5        price               Nullable(Float64)
# 6       volume                 Nullable(Int64)
# 7         side                  FixedString(1)
# 8         type                  FixedString(1)
# 9   trade_flag                  FixedString(1)
# 10        chno                          UInt64
# 11       bidno                 Nullable(Int64)
# 12       askno                 Nullable(Int64)
# 13       ordno                 Nullable(Int64)
# 14       seqno                          UInt64
# 15       ctype                  FixedString(1)
# 16      cbidno                 Nullable(Int64)
# 17      caskno                 Nullable(Int64)
#
# ...
